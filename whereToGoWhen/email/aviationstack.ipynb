# %%
import requests

params = {
  'access_key': '2494fe0f91eb1f3d38f7ad3e6c1318ee',
    'offset':500
}

api_result = requests.get('http://api.aviationstack.com/v1/flights?access_key=2494fe0f91eb1f3d38f7ad3e6c1318ee', params)

api_response = api_result.json()

# %%
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 500, 'count': 100, 'total': 1006},
#  'data': [{'flight_date': '2023-12-09',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-12-09T01:00:00+00:00',
#     'estimated': '2023-12-09T01:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '7',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-12-09T15:45:00+00:00',
#     'estimated': '2023-12-09T15:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
# ...

# %%
len(api_response)
# Out:
# 2
